# %%
import pandas as pd

# %%
pop_density = pd.read_csv(r'C:\Users\pc\Downloads\Energy_Access_&_Electrification_Planning_in_Africa\population_density\dza_pd_2020_1km_ASCII_XYZ.csv')
pop_density
# Out:
#                 X          Y          Z
# 0        7.202917  37.095417   7.981359
# 1        6.402917  37.087083  31.003132
# 2        6.411250  37.087083  29.725697
# 3        6.419583  37.087083  33.242626
# 4        6.427917  37.087083  26.576550
# ...           ...        ...        ...
# 3061266  3.394583  18.978750   0.175412
# 3061267  3.327917  18.970417   0.168226
# 3061268  3.336250  18.970417   0.170702
# 3061269  3.344583  18.970417   0.173790
# 3061270  3.352917  18.970417   0.176722
#
# [3061271 rows x 3 columns]
